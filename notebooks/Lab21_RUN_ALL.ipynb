# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.64s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = ""         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=full
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 4.97MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 37.7MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 87.5MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 115MB/s]
#
# tokenizer.json: downloading bytes:  21% 4.16M/20.0M [00:00<00:02, 7.19MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 10.1MB/s,  616kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 32.3MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.23MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 5.06MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 21.7MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# target=50  regression=15  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 151MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/9.32G [00:00<?, ?B/s]
# Downloading bytes:   1% 52.8M/9.32G [00:00<01:57, 78.6MB/s, 43.0MB/s  ]
# Downloading bytes:   3% 273M/9.32G [00:01<00:39, 229MB/s,  223MB/s  ]
# Downloading bytes:   4% 326M/9.32G [00:02<01:02, 143MB/s,  165MB/s  ]
# Downloading bytes:   5% 445M/9.32G [00:02<00:41, 216MB/s,  199MB/s  ]
# Downloading bytes:   5% 471M/9.32G [00:02<00:39, 226MB/s,  216MB/s  ]
# Downloading bytes:   7% 685M/9.32G [00:03<00:28, 301MB/s,  298MB/s  ]
# Downloading bytes:   9% 884M/9.32G [00:04<00:27, 303MB/s,  298MB/s  ]
# Downloading bytes:  10% 920M/9.32G [00:04<00:38, 218MB/s,  303MB/s  ]
# Downloading bytes:  21% 1.97G/9.32G [00:08<00:30, 238MB/s,  286MB/s  ]
# Downloading bytes:  29% 2.72G/9.32G [00:12<00:25, 264MB/s,  259MB/s  ]
# Downloading bytes:  35% 3.26G/9.32G [00:16<00:40, 148MB/s,  140MB/s  ]
# Downloading bytes:  35% 3.28G/9.32G [00:16<00:46, 130MB/s,  148MB/s  ]
# Downloading bytes:  37% 3.44G/9.32G [00:17<00:31, 187MB/s,  185MB/s  ]
# Downloading bytes:  47% 4.40G/9.32G [00:21<00:16, 293MB/s,  277MB/s  ]
# Downloading bytes:  48% 4.43G/9.32G [00:22<00:36, 133MB/s,  293MB/s  ]
# Downloading bytes:  52% 4.88G/9.32G [00:23<00:13, 341MB/s,  303MB/s  ]
# Downloading bytes:  53% 4.95G/9.32G [00:29<02:32, 28.6MB/s, 23.3MB/s  ]
# Downloading bytes:  55% 5.10G/9.32G [00:30<00:43, 96.9MB/s, 81.7MB/s  ]
# Downloading bytes:  62% 5.80G/9.32G [00:33<00:20, 172MB/s,  247MB/s  ]
# Downloading bytes:  68% 6.32G/9.32G [00:36<00:09, 319MB/s,  316MB/s  ]
# Downloading bytes:  71% 6.63G/9.32G [00:39<00:16, 167MB/s,  179MB/s  ]
# Reconstructing (incomplete total...):  53% 4.92G/9.32G [00:41<00:33, 132MB/s,  141MB/s  ]
# Downloading bytes:  73% 6.81G/9.32G [00:42<00:20, 125MB/s,  104MB/s  ]
# Downloading bytes:  74% 6.91G/9.32G [00:42<00:14, 169MB/s,  156MB/s  ]
# Downloading bytes:  77% 7.17G/9.32G [00:44<00:11, 191MB/s,  188MB/s  ]
# Downloading bytes:  78% 7.22G/9.32G [00:44<00:12, 174MB/s,  162MB/s  ]
# Downloading bytes:  84% 7.82G/9.32G [00:46<00:04, 327MB/s,  338MB/s  ]
# Downloading bytes:  86% 8.04G/9.32G [00:54<00:16, 78.9MB/s, 63.9MB/s  ]
# Reconstructing (incomplete total...):  70% 6.51G/9.32G [01:03<01:04, 43.4MB/s, 73.0MB/s  ]
# Reconstructing (incomplete total...):  80% 7.46G/9.32G [01:07<00:15, 116MB/s, 43.4MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [01:09<00:16, 78.9MB/s, 78.9MB/s  ]
# Reconstructing (incomplete total...):  81% 7.56G/9.32G [01:12<00:19, 88.3MB/s,  116MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:12<01:12, 72.57s/it]
# Reconstructing (incomplete total...):  85% 7.93G/9.32G [01:13<00:12, 115MB/s, 88.3MB/s  ]
# Reconstructing (incomplete total...):  90% 8.35G/9.32G [01:14<00:06, 139MB/s,  115MB/s  ]
# Reconstructing (incomplete total...):  91% 8.52G/9.32G [01:15<00:05, 149MB/s,  139MB/s  ]
# Reconstructing (incomplete total...):  95% 8.85G/9.32G [01:17<00:03, 142MB/s,  149MB/s  ]
# Reconstructing (incomplete total...):  97% 9.07G/9.32G [01:18<00:01, 163MB/s,  142MB/s  ]
# Reconstructing (incomplete total...):  99% 9.23G/9.32G [01:19<00:00, 177MB/s,  163MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [01:19<00:00, 184MB/s,  177MB/s  ]
#
# Fetching 2 files: 100% 2/2 [01:19<00:00, 39.78s/it]
# Download complete: 100% 8.05G/8.05G [01:19<00:00, 78.9MB/s, 78.9MB/s  ]
# Download complete: 100% 8.05G/8.05G [01:19<00:00, 101MB/s, 78.9MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [01:19<00:00, 117MB/s,  184MB/s  ]
# Loading weights: 100% 426/426 [00:31<00:00, 13.58it/s]
#   [(a) base + naive prompt/target] batch 1/13     14s elapsed  ~  170s left
#   [(a) base + naive prompt/target] batch 2/13     26s elapsed  ~  144s left
#   [(a) base + naive prompt/target] batch 3/13     38s elapsed  ~  127s left
#   [(a) base + naive prompt/target] batch 4/13     50s elapsed  ~  112s left
#   [(a) base + naive prompt/target] batch 5/13     62s elapsed  ~   99s left
#   [(a) base + naive prompt/target] batch 6/13     74s elapsed  ~   86s left
#   [(a) base + naive prompt/target] batch 7/13     86s elapsed  ~   73s left
#   [(a) base + naive prompt/target] batch 8/13     97s elapsed  ~   61s left
#   [(a) base + naive prompt/target] batch 9/13    109s elapsed  ~   48s left
#   [(a) base + naive prompt/target] batch 10/13    121s elapsed  ~   36s left
#   [(a) base + naive prompt/target] batch 11/13    133s elapsed  ~   24s left
#   [(a) base + naive prompt/target] batch 12/13    144s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 13/13    156s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 50 prompts in 156s
#   [(a) base + naive prompt/regression] batch 1/4      5s elapsed  ~   15s left
#   [(a) base + naive prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(a) base + naive prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(a) base + naive prompt/regression] batch 4/4     27s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 15 prompts in 27s
# (a) base + naive prompt      target=0.000  regression=0.758  format=0.000  3125ms
#   [(b) base + optimized prompt/target] batch 1/13      4s elapsed  ~   47s left
#   [(b) base + optimized prompt/target] batch 2/13      8s elapsed  ~   43s left
#   [(b) base + optimized prompt/target] batch 3/13     12s elapsed  ~   39s left
#   [(b) base + optimized prompt/target] batch 4/13     15s elapsed  ~   35s left
#   [(b) base + optimized prompt/target] batch 5/13     19s elapsed  ~   31s left
#   [(b) base + optimized prompt/target] batch 6/13     24s elapsed  ~   27s left
#   [(b) base + optimized prompt/target] batch 7/13     27s elapsed  ~   23s left
#   [(b) base + optimized prompt/target] batch 8/13     31s elapsed  ~   19s left
#   [(b) base + optimized prompt/target] batch 9/13     35s elapsed  ~   16s left
#   [(b) base + optimized prompt/target] batch 10/13     39s elapsed  ~   12s left
#   [(b) base + optimized prompt/target] batch 11/13     42s elapsed  ~    8s left
#   [(b) base + optimized prompt/target] batch 12/13     47s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 13/13     50s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 50 prompts in 50s
#   [(b) base + optimized prompt/regression] batch 1/4      5s elapsed  ~   14s left
#   [(b) base + optimized prompt/regression] batch 2/4     12s elapsed  ~   12s left
#   [(b) base + optimized prompt/regression] batch 3/4     19s elapsed  ~    6s left
#   [(b) base + optimized prompt/regression] batch 4/4     26s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 15 prompts in 26s
# (b) base + optimized prompt  target=0.765  regression=0.758  format=1.000  999ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.7577777777777778,
#     "format": 0.0,
#     "latency_ms": 3125.0429468999982,
#     "n": 50,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.765,
#     "regression": 0.7577777777777778,
#     "format": 1.0,
#     "latency_ms": 998.8475861200016,
#     "n": 50,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 50,
#   "n_regression": 15,
#   "eval_limit": null,
#   "smoke_mode": false
# }
#
# -- NB2 ok in 386s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1077.12it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.36it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6313.60 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46458.84 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.386', 'grad_norm': '2.614', 'learning_rate': '8.83e-05', 'entropy': '1.033', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7688', 'epoch': '0.7111'}
# {'loss': '0.1447', 'grad_norm': '0.6092', 'learning_rate': '6.434e-05', 'entropy': '0.2768', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9569', 'epoch': '1'}
# {'loss': '0.03013', 'grad_norm': '0.7522', 'learning_rate': '3.566e-05', 'entropy': '0.04526', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9892', 'epoch': '1.356'}
# {'loss': '0.02102', 'grad_norm': '0.2501', 'learning_rate': '1.17e-05', 'entropy': '0.0221', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9933', 'epoch': '1.711'}
# {'loss': '0.02724', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01674', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9954', 'epoch': '2'}
# {'train_runtime': '953.8', 'train_samples_per_second': '0.472', 'train_steps_per_second': '0.031', 'train_loss': '0.6288', 'epoch': '2'}
# 100% 30/30 [15:53<00:00, 31.79s/it]
# train 954s  final loss 0.6288
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 954.2,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6288,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1015s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 973.50it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.39it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 932.69it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.36it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6608.16 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 44247.86 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.777', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8276', 'grad_norm': '1.813', 'learning_rate': '8.83e-05', 'entropy': '0.9417', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8415', 'epoch': '0.7111'}
# {'loss': '0.1476', 'grad_norm': '1.248', 'learning_rate': '6.434e-05', 'entropy': '0.2866', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9595', 'epoch': '1'}
# {'loss': '0.04038', 'grad_norm': '0.8657', 'learning_rate': '3.566e-05', 'entropy': '0.06561', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9867', 'epoch': '1.356'}
# {'loss': '0.02215', 'grad_norm': '0.2105', 'learning_rate': '1.17e-05', 'entropy': '0.03201', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9912', 'epoch': '1.711'}
# {'loss': '0.02538', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02303', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '781', 'train_samples_per_second': '0.615', 'train_steps_per_second': '0.038', 'train_loss': '0.5378', 'epoch': '2'}
# 100% 30/30 [13:01<00:00, 26.03s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1215.56it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.33it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 9694.67 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46044.03 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '910.9', 'train_samples_per_second': '0.527', 'train_steps_per_second': '0.033', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:10<00:00, 30.36s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 856.94it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.17it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 9898.14 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 43977.74 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '985', 'train_samples_per_second': '0.487', 'train_steps_per_second': '0.03', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:25<00:00, 32.83s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6288 | 954.2 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5378 | 781.3 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 911.3 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 985.5 | 7.09 |
#
# -- NB4 ok in 2855s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.765 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 791.30it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.25it/s]
#   [ft/target] batch 1/13      7s elapsed  ~   84s left
#   [ft/target] batch 2/13     12s elapsed  ~   68s left
#   [ft/target] batch 3/13     17s elapsed  ~   58s left
#   [ft/target] batch 4/13     23s elapsed  ~   52s left
#   [ft/target] batch 5/13     28s elapsed  ~   45s left
#   [ft/target] batch 6/13     34s elapsed  ~   40s left
#   [ft/target] batch 7/13     39s elapsed  ~   33s left
#   [ft/target] batch 8/13     44s elapsed  ~   28s left
#   [ft/target] batch 9/13     49s elapsed  ~   22s left
#   [ft/target] batch 10/13     54s elapsed  ~   16s left
#   [ft/target] batch 11/13     59s elapsed  ~   11s left
#   [ft/target] batch 12/13     64s elapsed  ~    5s left
#   [ft/target] batch 13/13     70s elapsed  ~    0s left
#   [ft/target] done: 50 prompts in 70s
#   [ft/regression] batch 1/4     10s elapsed  ~   31s left
#   [ft/regression] batch 2/4     21s elapsed  ~   21s left
#   [ft/regression] batch 3/4     33s elapsed  ~   11s left
#   [ft/regression] batch 4/4     45s elapsed  ~    0s left
#   [ft/regression] done: 15 prompts in 45s
# fine-tune: {'target': 0.965, 'regression': 0.611111111111111, 'format': 1.0, 'latency_ms': 1403.935566479977, 'n': 50, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.7578 | 0.0 | 3125.0 | 50 |
# | (b) base + optimized prompt | 0.765 | 0.7578 | 1.0 | 998.8 | 50 |
# | (c) LoRA fine-tune | 0.965 | 0.6111 | 1.0 | 1403.9 | 50 |
# FAILED
#  - general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 936.75it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:35<00:00, 12.15it/s]
#   [attn_only/target] batch 1/13      3s elapsed  ~   39s left
#   [attn_only/target] batch 2/13      7s elapsed  ~   36s left
#   [attn_only/target] batch 3/13     10s elapsed  ~   35s left
#   [attn_only/target] batch 4/13     14s elapsed  ~   31s left
#   [attn_only/target] batch 5/13     17s elapsed  ~   27s left
#   [attn_only/target] batch 6/13     20s elapsed  ~   24s left
#   [attn_only/target] batch 7/13     24s elapsed  ~   20s left
#   [attn_only/target] batch 8/13     27s elapsed  ~   17s left
#   [attn_only/target] batch 9/13     30s elapsed  ~   13s left
#   [attn_only/target] batch 10/13     34s elapsed  ~   10s left
#   [attn_only/target] batch 11/13     37s elapsed  ~    7s left
#   [attn_only/target] batch 12/13     40s elapsed  ~    3s left
#   [attn_only/target] batch 13/13     44s elapsed  ~    0s left
#   [attn_only/target] done: 50 prompts in 44s
# attn_only: target=0.970  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1032.95it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.35it/s]
#   [wrong_lr/target] batch 1/13     19s elapsed  ~  228s left
#   [wrong_lr/target] batch 2/13     39s elapsed  ~  214s left
#   [wrong_lr/target] batch 3/13     58s elapsed  ~  194s left
#   [wrong_lr/target] batch 4/13     78s elapsed  ~  176s left
#   [wrong_lr/target] batch 5/13     98s elapsed  ~  157s left
#   [wrong_lr/target] batch 6/13    117s elapsed  ~  137s left
#   [wrong_lr/target] batch 7/13    137s elapsed  ~  117s left
#   [wrong_lr/target] batch 8/13    156s elapsed  ~   98s left
#   [wrong_lr/target] batch 9/13    176s elapsed  ~   78s left
#   [wrong_lr/target] batch 10/13    196s elapsed  ~   59s left
#   [wrong_lr/target] batch 11/13    215s elapsed  ~   39s left
#   [wrong_lr/target] batch 12/13    235s elapsed  ~   20s left
#   [wrong_lr/target] batch 13/13    254s elapsed  ~    0s left
#   [wrong_lr/target] done: 50 prompts in 254s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1053.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:36<00:00, 11.58it/s]
#   [qlora/target] batch 1/13      7s elapsed  ~   85s left
#   [qlora/target] batch 2/13     14s elapsed  ~   78s left
#   [qlora/target] batch 3/13     21s elapsed  ~   71s left
#   [qlora/target] batch 4/13     28s elapsed  ~   63s left
#   [qlora/target] batch 5/13     35s elapsed  ~   56s left
#   [qlora/target] batch 6/13     41s elapsed  ~   48s left
#   [qlora/target] batch 7/13     48s elapsed  ~   41s left
#   [qlora/target] batch 8/13     54s elapsed  ~   34s left
#   [qlora/target] batch 9/13     62s elapsed  ~   27s left
#   [qlora/target] batch 10/13     68s elapsed  ~   21s left
#   [qlora/target] batch 11/13     75s elapsed  ~   14s left
#   [qlora/target] batch 12/13     82s elapsed  ~    7s left
#   [qlora/target] batch 13/13     89s elapsed  ~    0s left
#   [qlora/target] done: 50 prompts in 89s
# qlora: target=0.940  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.965 | 1.0 | 1403.9 | 50 |
# | attn_only | 0.97 | 1.0 | 874.7 | 50 |
# | wrong_lr | 0.0 | 0.0 | 5079.3 | 50 |
# | qlora | 0.94 | 1.0 | 1776.8 | 50 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 12 | Shop ơi, mình đặt áo khoác gió mã đơn VN613097. Bị lỗi. Khi nào tiện.  | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "áo khoác gió", "sentiment" |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 47 | Cho mình hỏi, mình đặt ốp lưng điện thoại mã đơn DH936478. Shipper khô | 1.0 | {"intent": "van_chuyen", "urgency": "thap", "product": "ốp lưng điện thoại", "sentiment":  |
# | 48 | Alo shop, mình đặt ốp lưng điện thoại mã đơn DH734695. Giá bao nhiêu.  | 1.0 | {"intent": "hoi_thong_tin", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sen |
# | 49 | Chào shop, mình đặt ốp lưng điện thoại mã đơn VN833689. Sai màu. Sớm n | 1.0 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sent |
#
# -- NB5 ok in 681s
#
# ----------------------------------------
# stage timings
#   nb1        19s  (0.3 min)
#   nb2       386s  (6.4 min)
#   nb3      1015s  (16.9 min)
#   nb4      2855s  (47.6 min)
#   nb5       681s  (11.4 min)
#   total    4956s (82.6 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.74s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [  ok  ] full eval set used                               50 target items
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.765
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.200, regression Δ -0.147)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 24 passed · 1 warnings · 2 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 52
# drwxr-xr-x  2 root root  4096 Aug 21 06:42 .
# drwxr-xr-x 15 root root  4096 Aug 21 05:19 ..
# -rw-r--r--  1 root root   434 Aug 21 06:42 autopsy.json
# -rw-r--r--  1 root root   515 Aug 21 05:26 baselines_frozen.json
# -rw-r--r--  1 root root     0 Aug 21 05:18 .gitkeep
# -rw-r--r--  1 root root   592 Aug 21 05:19 mask_proof.json
# -rw-r--r--  1 root root 13678 Aug 21 06:42 qualitative.json
# -rw-r--r--  1 root root  1099 Aug 21 06:30 runs.csv
# -rw-r--r--  1 root root   277 Aug 21 05:19 template_check.json
# -rw-r--r--  1 root root   115 Aug 21 05:19 token_stats.json
# -rw-r--r--  1 root root   806 Aug 21 06:33 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,954.2,12.01,0.6288,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,781.3,12.02,0.5378,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,911.3,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,985.5,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.7578,
#       "format": 0.0,
#       "latency_ms": 3125.0,
#       "n": 50
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.765,
#       "regression": 0.7578,
#       "format": 1.0,
#       "latency_ms": 998.8,
#       "n": 50
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.965,
#       "regression": 0.6111,
#       "format": 1.0,
#       "latency_ms": 1403.9,
#       "n": 50
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.147 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.19999999999999996,
#     "regression_delta": -0.14666666666666672
#   },
#   "valid_trace_rate": 0.0
# }
